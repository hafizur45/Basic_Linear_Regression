# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizur45/Basic_Linear_Regression/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
#import plotly as plt
import seaborn as sn
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Dhaka Rent.csv',sep=';')

# %%
df
# Out:
#     area   rent
# 0   2000  31500
# 1   2100  35000
# 2   2500  41050
# 3   2250  36100
# 4   3000  52100
# 5   1900  32500
# 6   1500  20000
# 7   1850  24500
# 8   2700  48000
# 9   2100  31000
# 10  2150  34500
# 11  2100  32000
# 12  2100  34500
# 13  2510  40050
# 14  2250  34100
# 15  3100  51500
# 16  1800  30500
# 17  1550  21000
# 18  1800  25000
# 19  2700  47000
# 20  2110  31500
# 21  2100  33500
# 22  3500  70000
# 23  1200  20000
# 24  2800  50000
# 25  3100  53000
# 26  2750  48000
# 27  1800  25000
# 28  2200  31460
# 29  3100  51400
# 30  2100  33500
# 31  2100  35010
# 32  2500  41100
# 33  2250  35100
# 34  3000  52200
# 35  1900  32300
# 36  1500  20200
# 37  1850  24000
# 38  2700  47500
# 39  2100  31500
# 40  2150  34400
# 41  2100  32020
# 42  2100  34700
# 43  2510  40000
# 44  2250  35000
# 45  3100  51000
# 46  1800  30000
# 47  1550  21500
# 48  1800  25500
# 49  2700  47500
# 50  2110  31000
# 51  2100  33000
# 52  3500  70500
# 53  1200  20100
# ...

# %%
df.head()
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000
# 2  2500  41050
# 3  2250  36100
# 4  3000  52100

# %%
df.tail()
# Out:
#     area   rent
# 55  3100  54000
# 56  2750  48500
# 57  1800  25100
# 58  2200  31560
# 59  3100  51600

# %%
df.area
# Out:
# 0     2000
# 1     2100
# 2     2500
# 3     2250
# 4     3000
# 5     1900
# 6     1500
# 7     1850
# 8     2700
# 9     2100
# 10    2150
# 11    2100
# 12    2100
# 13    2510
# 14    2250
# 15    3100
# 16    1800
# 17    1550
# 18    1800
# 19    2700
# 20    2110
# 21    2100
# 22    3500
# 23    1200
# 24    2800
# 25    3100
# 26    2750
# 27    1800
# 28    2200
# 29    3100
# 30    2100
# 31    2100
# 32    2500
# 33    2250
# 34    3000
# 35    1900
# 36    1500
# 37    1850
# 38    2700
# 39    2100
# 40    2150
# 41    2100
# 42    2100
# 43    2510
# 44    2250
# 45    3100
# 46    1800
# 47    1550
# 48    1800
# 49    2700
# 50    2110
# 51    2100
# 52    3500
# 53    1200
# 54    2800
# 55    3100
# 56    2750
# 57    1800
# 58    2200
# 59    3100
# Name: area, dtype: int64

# %%
df.rent
# Out:
# 0     31500
# 1     35000
# 2     41050
# 3     36100
# 4     52100
# 5     32500
# 6     20000
# 7     24500
# 8     48000
# 9     31000
# 10    34500
# 11    32000
# 12    34500
# 13    40050
# 14    34100
# 15    51500
# 16    30500
# 17    21000
# 18    25000
# 19    47000
# 20    31500
# 21    33500
# 22    70000
# 23    20000
# 24    50000
# 25    53000
# 26    48000
# 27    25000
# 28    31460
# 29    51400
# 30    33500
# 31    35010
# 32    41100
# 33    35100
# 34    52200
# 35    32300
# 36    20200
# 37    24000
# 38    47500
# 39    31500
# 40    34400
# 41    32020
# 42    34700
# 43    40000
# 44    35000
# 45    51000
# 46    30000
# 47    21500
# 48    25500
# 49    47500
# 50    31000
# 51    33000
# 52    70500
# 53    20100
# 54    51000
# 55    54000
# 56    48500
# 57    25100
# 58    31560
# 59    51600
# Name: rent, dtype: int64

# %%
df.shape
# Out:
# (60, 2)

# %%
df[25:30]
# Out:
#     area   rent
# 25  3100  53000
# 26  2750  48000
# 27  1800  25000
# 28  2200  31460
# 29  3100  51400

# %%
plt.scatter(df.area,df.rent)
plt.xlabel('Rent In Taka')
plt.ylabel('size in sq')
plt.title('Rent')
# Out:
# Text(0.5, 1.0, 'Rent')

# %%
df.area.mean()
# Out:
# 2289.0

# %%
df.rent.mean()
# Out:
# 37269.166666666664

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('rent', axis=1), df['rent'], test_size=0.2, random_state=42)

# %%
xtest=X_test

# %%
X_train
# Out:
#     area
# 31  2100
# 3   2250
# 52  3500
# 17  1550
# 8   2700
# 6   1500
# 40  2150
# 4   3000
# 43  2510
# 19  2700
# 34  3000
# 58  2200
# 25  3100
# 56  2750
# 15  3100
# 27  1800
# 9   2100
# 30  2100
# 26  2750
# 16  1800
# 24  2800
# 55  3100
# 11  2100
# 32  2500
# 53  1200
# 41  2100
# 37  1850
# 29  3100
# 44  2250
# 1   2100
# 21  2100
# 2   2500
# 47  1550
# 39  2100
# 35  1900
# 23  1200
# 49  2700
# 10  2150
# 22  3500
# 18  1800
# 59  3100
# 20  2110
# 7   1850
# 42  2100
# 14  2250
# 28  2200
# 51  2100
# 38  2700

# %%
y_train
# Out:
# 31    35010
# 3     36100
# 52    70500
# 17    21000
# 8     48000
# 6     20000
# 40    34400
# 4     52100
# 43    40000
# 19    47000
# 34    52200
# 58    31560
# 25    53000
# 56    48500
# 15    51500
# 27    25000
# 9     31000
# 30    33500
# 26    48000
# 16    30500
# 24    50000
# 55    54000
# 11    32000
# 32    41100
# 53    20100
# 41    32020
# 37    24000
# 29    51400
# 44    35000
# 1     35000
# 21    33500
# 2     41050
# 47    21500
# 39    31500
# 35    32300
# 23    20000
# 49    47500
# 10    34500
# 22    70000
# 18    25000
# 59    51600
# 20    31500
# 7     24500
# 42    34700
# 14    34100
# 28    31460
# 51    33000
# 38    47500
# Name: rent, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict([[2500]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41826.77576875])

# %%
m=reg.coef_

# %%
c=reg.intercept_

# %%
m
# Out:
# array([21.48682316])

# %%
c
# Out:
# -11890.282124432139

# %%
pred = m*2500 + c

# %%
pred
# Out:
# array([41826.77576875])

# %%
df2=df.copy()

# %%
df2
# Out:
#     area   rent
# 0   2000  31500
# 1   2100  35000
# 2   2500  41050
# 3   2250  36100
# 4   3000  52100
# 5   1900  32500
# 6   1500  20000
# 7   1850  24500
# 8   2700  48000
# 9   2100  31000
# 10  2150  34500
# 11  2100  32000
# 12  2100  34500
# 13  2510  40050
# 14  2250  34100
# 15  3100  51500
# 16  1800  30500
# 17  1550  21000
# 18  1800  25000
# 19  2700  47000
# 20  2110  31500
# 21  2100  33500
# 22  3500  70000
# 23  1200  20000
# 24  2800  50000
# 25  3100  53000
# 26  2750  48000
# 27  1800  25000
# 28  2200  31460
# 29  3100  51400
# 30  2100  33500
# 31  2100  35010
# 32  2500  41100
# 33  2250  35100
# 34  3000  52200
# 35  1900  32300
# 36  1500  20200
# 37  1850  24000
# 38  2700  47500
# 39  2100  31500
# 40  2150  34400
# 41  2100  32020
# 42  2100  34700
# 43  2510  40000
# 44  2250  35000
# 45  3100  51000
# 46  1800  30000
# 47  1550  21500
# 48  1800  25500
# 49  2700  47500
# 50  2110  31000
# 51  2100  33000
# 52  3500  70500
# 53  1200  20100
# ...

# %%
df2['predicted'] = reg.predict(df[['area']])

# %%
df2
# Out:
#     area   rent     predicted
# 0   2000  31500  31083.364190
# 1   2100  35000  33232.046506
# 2   2500  41050  41826.775769
# 3   2250  36100  36455.069979
# 4   3000  52100  52570.187347
# 5   1900  32500  28934.681874
# 6   1500  20000  20339.952611
# 7   1850  24500  27860.340717
# 8   2700  48000  46124.140400
# 9   2100  31000  33232.046506
# 10  2150  34500  34306.387664
# 11  2100  32000  33232.046506
# 12  2100  34500  33232.046506
# 13  2510  40050  42041.644000
# 14  2250  34100  36455.069979
# 15  3100  51500  54718.869663
# 16  1800  30500  26785.999559
# 17  1550  21000  21414.293769
# 18  1800  25000  26785.999559
# 19  2700  47000  46124.140400
# 20  2110  31500  33446.914737
# 21  2100  33500  33232.046506
# 22  3500  70000  63313.598926
# 23  1200  20000  13893.905664
# 24  2800  50000  48272.822716
# 25  3100  53000  54718.869663
# 26  2750  48000  47198.481558
# 27  1800  25000  26785.999559
# 28  2200  31460  35380.728822
# 29  3100  51400  54718.869663
# ...

# %%
df2.head()
# Out:
#    area   rent     predicted
# 0  2000  31500  31083.364190
# 1  2100  35000  33232.046506
# 2  2500  41050  41826.775769
# 3  2250  36100  36455.069979
# 4  3000  52100  52570.187347
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['area'].plot(kind='hist', bins=20, title='area')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rent'].plot(kind='hist', bins=20, title='rent')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['predicted'].plot(kind='hist', bins=20, title='predicted')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
plt.scatter(df.area,df.rent,color = 'green',marker = '*')
plt.plot(xtest,reg.predict(xtest),color = 'red')
plt.xlabel('Rent In Taka')
plt.ylabel('size in sq')
plt.title('Dhaka Rent data')
# Out:
# Text(0.5, 1.0, 'Dhaka Rent data')

# %%
from sklearn.metrics import mean_squared_error as ms,mean_absolute_error as ma

# %%
#test mse
test_mse =ms(y_test,reg.predict(xtest))

# %%
test_mse
# Out:
# 5199691.621721148

# %%
#train mse
train_mse =ms(y_train,reg.predict(X_train))

# %%
train_mse
# Out:
# 7186843.190818119

# %%
#test mae
test_mae =ma(y_test,reg.predict(xtest))

# %%
test_mae
# Out:
# 1984.6279386790573

# %%
#train mae
train_mae =ma(y_train,reg.predict(X_train))

# %%
train_mae
# Out:
# 2021.6941803100708

# %% [markdown]
# Accuracy

# %%
reg.score(xtest,y_test)
# Out:
# 0.9370648048191109

# %%
reg.score(X_train,y_train)
# Out:
# 0.9508465043158032

# %%
import joblib,pickle

# %%
pickle.dump(reg,open('pik1','wb'))
